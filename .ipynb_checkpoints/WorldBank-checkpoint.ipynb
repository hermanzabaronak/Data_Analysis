# %% [markdown]
# # worldbank

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("D:\WorldBank\API_NY.GDP.PCAP.PP.KD_DS2_en_csv_v2_5734697.csv", skiprows= 4)

# %%
df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD   NaN
# 1  GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD   NaN
# 2  GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD   NaN
# 3  GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD   NaN
# 4  GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD   NaN
#
#    1961  1962  1963  1964  1965  ...          2014          2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  35467.235764  36490.524457
# 1   NaN   NaN   NaN   NaN   NaN  ...   3642.875373   3658.533588
# ...

# %%
country_list = ['Belarus','Poland', 'Lithuania', 'Slovak Republic', 'Hungary', 'Czechia']

# %%
df['Country Name'].isin(country_list)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 261    False
# 262    False
# 263    False
# 264    False
# 265    False
# Name: Country Name, Length: 266, dtype: bool

# %%
country_df = df[df['Country Name'].isin(country_list)]
country_df
# Out:
#         Country Name Country Code  \
# 25           Belarus          BLR
# 54           Czechia          CZE
# 101          Hungary          HUN
# 143        Lithuania          LTU
# 190           Poland          POL
# 221  Slovak Republic          SVK
#
#                                         Indicator Name     Indicator Code  \
# 25   GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD
# 54   GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD
# 101  GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD
# 143  GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD
# 190  GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD
# 221  GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD
#
#      1960  1961  1962  1963  1964  1965  ...          2014          2015  \
# 25    NaN   NaN   NaN   NaN   NaN   NaN  ...  19119.312138  18362.695254
# ...

# %%
column_list = ['Country Name']
starting_point = 1995
end_point = 2022
while starting_point <= end_point:
    column_entry = str(starting_point)
    column_list.append(column_entry)
    starting_point += 1

# %%
column_list
# Out:
# ['Country Name',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022']

# %%
country_df[column_list]
# Out:
#         Country Name          1995          1996          1997          1998  \
# 25           Belarus   5805.362809   5988.039352   6698.457478   7293.907780
# 54           Czechia  22758.596812  23756.978386  23659.320794  23597.306180
# 101          Hungary  16612.370897  16654.645095  17212.762684  17925.722167
# 143        Lithuania  10640.360031  11274.640108  12302.101204  13317.907729
# 190           Poland  12398.524127  13146.756086  13985.433576  14629.198357
# 221  Slovak Republic  13254.529397  14102.083624  14910.196003  15497.151155
#
#              1999          2000          2001          2002          2003  \
# 25    7575.917873   8053.173157   8477.083505   8961.640584   9660.193111
# 54   23948.385034  24976.506318  25833.414670  26289.626139  27239.559444
# 101  18528.635975  19408.921803  20246.045355  21266.438721  22196.373377
# 143  13259.616950  13846.683288  14872.379094  16004.438900  17839.782738
# ...
